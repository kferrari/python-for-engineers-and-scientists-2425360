# %% [markdown]
# # 04_03_pandas.ipynb - Data tables with Pandas

# %%
import requests

import numpy as np
import matplotlib.pyplot as pp
import pandas as pd
import astropy.units

# %%
# utility function from the last video

def dump(url, filename):
    r = requests.get(url)
    
    with open(filename, 'wb') as outfile:
        outfile.write(r.content)

# %%
# in case of network problems, you can use the file cache/gwtc-20210726.csv
dump('https://www.gw-openscience.org/eventapi/csv/GWTC', 'gwtc.csv')

# %%
gwtc = pd.read_csv('gwtc.csv')

# %%
gwtc
# Out:
#                     id       commonName  version catalog.shortName  \
# 0          GW150914-v3         GW150914        3  GWTC-1-confident
# 1          GW151012-v3         GW151012        3  GWTC-1-confident
# 2          GW151226-v2         GW151226        2  GWTC-1-confident
# 3          GW170104-v2         GW170104        2  GWTC-1-confident
# 4          GW170608-v3         GW170608        3  GWTC-1-confident
# ..                 ...              ...      ...               ...
# 88  GW200306_093714-v1  GW200306_093714        1  GWTC-3-confident
# 89  GW200308_173609-v1  GW200308_173609        1  GWTC-3-confident
# 90  GW200311_115853-v1  GW200311_115853        1  GWTC-3-confident
# 91  GW200316_215756-v1  GW200316_215756        1  GWTC-3-confident
# 92  GW200322_091133-v1  GW200322_091133        1  GWTC-3-confident
#
#              GPS                          reference  \
# 0   1.126259e+09  https://doi.org/10.7935/82H3-HH23
# 1   1.128679e+09  https://doi.org/10.7935/82H3-HH23
# 2   1.135136e+09  https://doi.org/10.7935/82H3-HH23
# 3   1.167560e+09  https://doi.org/10.7935/82H3-HH23
# 4   1.180922e+09  https://doi.org/10.7935/82H3-HH23
# ..           ...                                ...
# 88  1.267523e+09                           /GWTC-3/
# 89  1.267724e+09                           /GWTC-3/
# 90  1.267963e+09                           /GWTC-3/
# 91  1.268431e+09                           /GWTC-3/
# 92  1.268904e+09                           /GWTC-3/
#
#                                               jsonurl  mass_1_source  \
# 0   https://gwosc.org/eventapi/json/GWTC-1-confide...           35.6
# 1   https://gwosc.org/eventapi/json/GWTC-1-confide...           23.2
# 2   https://gwosc.org/eventapi/json/GWTC-1-confide...           13.7
# 3   https://gwosc.org/eventapi/json/GWTC-1-confide...           30.8
# 4   https://gwosc.org/eventapi/json/GWTC-1-confide...           11.0
# ..                                                ...            ...
# 88  https://gwosc.org/eventapi/json/GWTC-3-confide...           28.3
# 89  https://gwosc.org/eventapi/json/GWTC-3-confide...           36.4
# 90  https://gwosc.org/eventapi/json/GWTC-3-confide...           34.2
# 91  https://gwosc.org/eventapi/json/GWTC-3-confide...           13.1
# 92  https://gwosc.org/eventapi/json/GWTC-3-confide...           34.0
#
#     mass_1_source_lower  mass_1_source_upper  ...  redshift_upper  \
# 0                  -3.1                  4.7  ...            0.03
# 1                  -5.5                 14.9  ...            0.09
# 2                  -3.2                  8.8  ...            0.04
# 3                  -5.6                  7.3  ...            0.08
# 4                  -1.7                  5.5  ...            0.02
# ..                  ...                  ...  ...             ...
# 88                 -7.7                 17.1  ...            0.24
# 89                 -9.6                 11.2  ...            0.32
# 90                 -3.8                  6.4  ...            0.05
# 91                 -2.9                 10.2  ...            0.08
# 92                -18.0                 48.0  ...            0.84
#
#              far  far_lower  far_upper  p_astro  p_astro_lower  p_astro_upper  \
# 0   1.000000e-07        NaN        NaN  1.00000            NaN            NaN
# 1   7.920000e-03        NaN        NaN  1.00000            NaN            NaN
# 2   1.000000e-07        NaN        NaN  1.00000            NaN            NaN
# 3   1.000000e-07        NaN        NaN  1.00000            NaN            NaN
# 4   1.000000e-07        NaN        NaN  1.00000            NaN            NaN
# ..           ...        ...        ...      ...            ...            ...
# 88  2.400000e+01        NaN        NaN  0.81156            NaN            NaN
# 89  2.400000e+00        NaN        NaN  0.85660            NaN            NaN
# 90  1.000000e-05        NaN        NaN  0.99000            NaN            NaN
# 91  1.000000e-05        NaN        NaN  0.99000            NaN            NaN
# 92  1.400000e+02        NaN        NaN  0.61501            NaN            NaN
#
#     final_mass_source  final_mass_source_lower  final_mass_source_upper
# 0                63.1                     -3.0                      3.4
# 1                35.6                     -3.8                     10.8
# 2                20.5                     -1.5                      6.4
# 3                48.9                     -4.0                      5.1
# 4                17.8                     -0.7                      3.4
# ..                ...                      ...                      ...
# 88               41.7                     -6.9                     12.3
# 89               47.4                     -7.7                     11.1
# 90               59.0                     -3.9                      4.8
# 91               20.2                     -1.9                      7.4
# 92               53.0                    -26.0                     38.0
#
# [93 rows x 43 columns]

# %%
gwtc.head()
# Out:
#             id commonName  version catalog.shortName           GPS  \
# 0  GW150914-v3   GW150914        3  GWTC-1-confident  1.126259e+09
# 1  GW151012-v3   GW151012        3  GWTC-1-confident  1.128679e+09
# 2  GW151226-v2   GW151226        2  GWTC-1-confident  1.135136e+09
# 3  GW170104-v2   GW170104        2  GWTC-1-confident  1.167560e+09
# 4  GW170608-v3   GW170608        3  GWTC-1-confident  1.180922e+09
#
#                            reference  \
# 0  https://doi.org/10.7935/82H3-HH23
# 1  https://doi.org/10.7935/82H3-HH23
# 2  https://doi.org/10.7935/82H3-HH23
# 3  https://doi.org/10.7935/82H3-HH23
# 4  https://doi.org/10.7935/82H3-HH23
#
#                                              jsonurl  mass_1_source  \
# 0  https://gwosc.org/eventapi/json/GWTC-1-confide...           35.6
# 1  https://gwosc.org/eventapi/json/GWTC-1-confide...           23.2
# 2  https://gwosc.org/eventapi/json/GWTC-1-confide...           13.7
# 3  https://gwosc.org/eventapi/json/GWTC-1-confide...           30.8
# 4  https://gwosc.org/eventapi/json/GWTC-1-confide...           11.0
#
#    mass_1_source_lower  mass_1_source_upper  ...  redshift_upper  \
# 0                 -3.1                  4.7  ...            0.03
# 1                 -5.5                 14.9  ...            0.09
# 2                 -3.2                  8.8  ...            0.04
# 3                 -5.6                  7.3  ...            0.08
# 4                 -1.7                  5.5  ...            0.02
#
#             far  far_lower  far_upper  p_astro  p_astro_lower  p_astro_upper  \
# 0  1.000000e-07        NaN        NaN      1.0            NaN            NaN
# 1  7.920000e-03        NaN        NaN      1.0            NaN            NaN
# 2  1.000000e-07        NaN        NaN      1.0            NaN            NaN
# 3  1.000000e-07        NaN        NaN      1.0            NaN            NaN
# 4  1.000000e-07        NaN        NaN      1.0            NaN            NaN
#
#    final_mass_source  final_mass_source_lower  final_mass_source_upper
# 0               63.1                     -3.0                      3.4
# 1               35.6                     -3.8                     10.8
# 2               20.5                     -1.5                      6.4
# 3               48.9                     -4.0                      5.1
# 4               17.8                     -0.7                      3.4
#
# [5 rows x 43 columns]

# %%
gwtc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 43 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                93 non-null     object
#  1   commonName                        93 non-null     object
#  2   version                           93 non-null     int64
#  3   catalog.shortName                 93 non-null     object
#  4   GPS                               93 non-null     float64
#  5   reference                         93 non-null     object
#  6   jsonurl                           93 non-null     object
#  7   mass_1_source                     90 non-null     float64
#  8   mass_1_source_lower               90 non-null     float64
#  9   mass_1_source_upper               90 non-null     float64
#  10  mass_2_source                     90 non-null     float64
#  11  mass_2_source_lower               90 non-null     float64
#  12  mass_2_source_upper               90 non-null     float64
#  13  network_matched_filter_snr        93 non-null     float64
#  14  network_matched_filter_snr_lower  85 non-null     float64
#  15  network_matched_filter_snr_upper  85 non-null     float64
#  16  luminosity_distance               90 non-null     float64
#  17  luminosity_distance_lower         90 non-null     float64
#  18  luminosity_distance_upper         90 non-null     float64
#  19  chi_eff                           90 non-null     float64
#  20  chi_eff_lower                     90 non-null     float64
#  21  chi_eff_upper                     90 non-null     float64
#  22  total_mass_source                 79 non-null     float64
#  23  total_mass_source_lower           79 non-null     float64
#  24  total_mass_source_upper           79 non-null     float64
#  25  chirp_mass_source                 90 non-null     float64
#  26  chirp_mass_source_lower           90 non-null     float64
#  27  chirp_mass_source_upper           90 non-null     float64
#  28  chirp_mass                        0 non-null      float64
#  29  chirp_mass_lower                  0 non-null      float64
#  30  chirp_mass_upper                  0 non-null      float64
#  31  redshift                          90 non-null     float64
#  32  redshift_lower                    90 non-null     float64
#  33  redshift_upper                    90 non-null     float64
#  34  far                               93 non-null     float64
#  35  far_lower                         0 non-null      float64
#  36  far_upper                         0 non-null      float64
#  37  p_astro                           92 non-null     float64
#  38  p_astro_lower                     0 non-null      float64
#  39  p_astro_upper                     0 non-null      float64
#  40  final_mass_source                 89 non-null     float64
#  41  final_mass_source_lower           88 non-null     float64
#  42  final_mass_source_upper           88 non-null     float64
# dtypes: float64(37), int64(1), object(5)
# memory usage: 31.4+ KB

# %%
gwtc.describe()
# Out:
#          version           GPS  mass_1_source  mass_1_source_lower  \
# count  93.000000  9.300000e+01      90.000000            90.000000
# mean    1.623656  1.243403e+09      35.051778            -7.675556
# std     0.721019  3.010448e+07      20.441006             6.268708
# min     1.000000  1.126259e+09       1.460000           -33.000000
# 25%     1.000000  1.241816e+09      21.400000            -9.600000
# 50%     2.000000  1.251009e+09      35.250000            -6.000000
# 75%     2.000000  1.260808e+09      42.150000            -3.200000
# max     4.000000  1.268904e+09     105.500000            -0.100000
#
#        mass_1_source_upper  mass_2_source  mass_2_source_lower  \
# count            90.000000      90.000000            90.000000
# mean             12.838000      21.656778            -6.974000
# std              13.909136      14.047920             6.161799
# min               0.120000       1.170000           -36.500000
# 25%               5.650000       8.225000            -9.275000
# 50%               9.500000      22.750000            -5.850000
# 75%              14.075000      29.000000            -2.425000
# max             104.000000      76.000000            -0.060000
#
#        mass_2_source_upper  network_matched_filter_snr  \
# count            90.000000                   93.000000
# mean              6.980889                   12.273784
# std               6.091423                    4.833748
# min               0.070000                    6.000000
# 25%               2.250000                    9.047895
# 50%               5.350000                   10.800000
# 75%               9.275000                   13.200000
# max              27.100000                   33.000000
#
#        network_matched_filter_snr_lower  ...  redshift_upper           far  \
# count                         85.000000  ...       90.000000  9.300000e+01
# mean                          -0.484706  ...        0.183111  3.309618e+00
# std                            0.224407  ...        0.161271  1.536689e+01
# min                           -1.200000  ...        0.000000  1.000000e-07
# 25%                           -0.600000  ...        0.062500  1.000000e-05
# 50%                           -0.400000  ...        0.115000  1.300000e-03
# 75%                           -0.300000  ...        0.260000  4.600000e-01
# max                           -0.200000  ...        0.840000  1.400000e+02
#
#        far_lower  far_upper    p_astro  p_astro_lower  p_astro_upper  \
# count        0.0        0.0  92.000000            0.0            0.0
# mean         NaN        NaN   0.906656            NaN            NaN
# std          NaN        NaN   0.168050            NaN            NaN
# min          NaN        NaN   0.121102            NaN            NaN
# 25%          NaN        NaN   0.854410            NaN            NaN
# 50%          NaN        NaN   0.990000            NaN            NaN
# 75%          NaN        NaN   1.000000            NaN            NaN
# max          NaN        NaN   1.000000            NaN            NaN
#
#        final_mass_source  final_mass_source_lower  final_mass_source_upper
# count          89.000000                88.000000                88.000000
# mean           54.891461                -7.706250                12.296136
# std            31.463760                 6.759232                13.785560
# min             2.800000               -33.600000                 1.300000
# 25%            32.100000               -11.000000                 4.075000
# 50%            55.500000                -6.500000                 8.550000
# 75%            68.600000                -2.775000                16.000000
# max           172.900000                -0.660000               100.000000
#
# [8 rows x 38 columns]

# %%
gwtc_i = gwtc.set_index('id').sort_index()

# %%
gwtc_i.head()
# Out:
#             commonName  version catalog.shortName           GPS  \
# id
# GW150914-v3   GW150914        3  GWTC-1-confident  1.126259e+09
# GW151012-v3   GW151012        3  GWTC-1-confident  1.128679e+09
# GW151226-v2   GW151226        2  GWTC-1-confident  1.135136e+09
# GW170104-v2   GW170104        2  GWTC-1-confident  1.167560e+09
# GW170608-v3   GW170608        3  GWTC-1-confident  1.180922e+09
#
#                                      reference  \
# id
# GW150914-v3  https://doi.org/10.7935/82H3-HH23
# GW151012-v3  https://doi.org/10.7935/82H3-HH23
# GW151226-v2  https://doi.org/10.7935/82H3-HH23
# GW170104-v2  https://doi.org/10.7935/82H3-HH23
# GW170608-v3  https://doi.org/10.7935/82H3-HH23
#
#                                                        jsonurl  mass_1_source  \
# id
# GW150914-v3  https://gwosc.org/eventapi/json/GWTC-1-confide...           35.6
# GW151012-v3  https://gwosc.org/eventapi/json/GWTC-1-confide...           23.2
# GW151226-v2  https://gwosc.org/eventapi/json/GWTC-1-confide...           13.7
# GW170104-v2  https://gwosc.org/eventapi/json/GWTC-1-confide...           30.8
# GW170608-v3  https://gwosc.org/eventapi/json/GWTC-1-confide...           11.0
#
#              mass_1_source_lower  mass_1_source_upper  mass_2_source  ...  \
# id                                                                    ...
# GW150914-v3                 -3.1                  4.7           30.6  ...
# GW151012-v3                 -5.5                 14.9           13.6  ...
# GW151226-v2                 -3.2                  8.8            7.7  ...
# GW170104-v2                 -5.6                  7.3           20.0  ...
# GW170608-v3                 -1.7                  5.5            7.6  ...
#
#              redshift_upper           far  far_lower  far_upper  p_astro  \
# id
# GW150914-v3            0.03  1.000000e-07        NaN        NaN      1.0
# GW151012-v3            0.09  7.920000e-03        NaN        NaN      1.0
# GW151226-v2            0.04  1.000000e-07        NaN        NaN      1.0
# GW170104-v2            0.08  1.000000e-07        NaN        NaN      1.0
# GW170608-v3            0.02  1.000000e-07        NaN        NaN      1.0
#
#              p_astro_lower  p_astro_upper  final_mass_source  \
# id
# GW150914-v3            NaN            NaN               63.1
# GW151012-v3            NaN            NaN               35.6
# GW151226-v2            NaN            NaN               20.5
# GW170104-v2            NaN            NaN               48.9
# GW170608-v3            NaN            NaN               17.8
#
#              final_mass_source_lower  final_mass_source_upper
# id
# GW150914-v3                     -3.0                      3.4
# GW151012-v3                     -3.8                     10.8
# GW151226-v2                     -1.5                      6.4
# GW170104-v2                     -4.0                      5.1
# GW170608-v3                     -0.7                      3.4
#
# [5 rows x 42 columns]

# %%
gwtc_i.loc['GW150914-v3']
# Out:
# commonName                                                                   GW150914
# version                                                                             3
# catalog.shortName                                                    GWTC-1-confident
# GPS                                                                      1126259462.4
# reference                                           https://doi.org/10.7935/82H3-HH23
# jsonurl                             https://gwosc.org/eventapi/json/GWTC-1-confide...
# mass_1_source                                                                    35.6
# mass_1_source_lower                                                              -3.1
# mass_1_source_upper                                                               4.7
# mass_2_source                                                                    30.6
# mass_2_source_lower                                                              -4.4
# mass_2_source_upper                                                               3.0
# network_matched_filter_snr                                                       26.0
# network_matched_filter_snr_lower                                                 -0.2
# network_matched_filter_snr_upper                                                  0.1
# luminosity_distance                                                             440.0
# luminosity_distance_lower                                                      -170.0
# luminosity_distance_upper                                                       150.0
# chi_eff                                                                         -0.01
# chi_eff_lower                                                                   -0.13
# chi_eff_upper                                                                    0.12
# total_mass_source                                                                 NaN
# total_mass_source_lower                                                           NaN
# total_mass_source_upper                                                           NaN
# chirp_mass_source                                                                28.6
# chirp_mass_source_lower                                                          -1.5
# chirp_mass_source_upper                                                           1.7
# chirp_mass                                                                        NaN
# chirp_mass_lower                                                                  NaN
# chirp_mass_upper                                                                  NaN
# redshift                                                                         0.09
# redshift_lower                                                                  -0.03
# redshift_upper                                                                   0.03
# far                                                                               0.0
# far_lower                                                                         NaN
# far_upper                                                                         NaN
# p_astro                                                                           1.0
# p_astro_lower                                                                     NaN
# p_astro_upper                                                                     NaN
# final_mass_source                                                                63.1
# final_mass_source_lower                                                          -3.0
# final_mass_source_upper                                                           3.4
# Name: GW150914-v3, dtype: object

# %%
gwtc_i.loc['GW150914-v3':'GW151226-v2']
# Out:
#             commonName  version catalog.shortName           GPS  \
# id
# GW150914-v3   GW150914        3  GWTC-1-confident  1.126259e+09
# GW151012-v3   GW151012        3  GWTC-1-confident  1.128679e+09
# GW151226-v2   GW151226        2  GWTC-1-confident  1.135136e+09
#
#                                      reference  \
# id
# GW150914-v3  https://doi.org/10.7935/82H3-HH23
# GW151012-v3  https://doi.org/10.7935/82H3-HH23
# GW151226-v2  https://doi.org/10.7935/82H3-HH23
#
#                                                        jsonurl  mass_1_source  \
# id
# GW150914-v3  https://gwosc.org/eventapi/json/GWTC-1-confide...           35.6
# GW151012-v3  https://gwosc.org/eventapi/json/GWTC-1-confide...           23.2
# GW151226-v2  https://gwosc.org/eventapi/json/GWTC-1-confide...           13.7
#
#              mass_1_source_lower  mass_1_source_upper  mass_2_source  ...  \
# id                                                                    ...
# GW150914-v3                 -3.1                  4.7           30.6  ...
# GW151012-v3                 -5.5                 14.9           13.6  ...
# GW151226-v2                 -3.2                  8.8            7.7  ...
#
#              redshift_upper           far  far_lower  far_upper  p_astro  \
# id
# GW150914-v3            0.03  1.000000e-07        NaN        NaN      1.0
# GW151012-v3            0.09  7.920000e-03        NaN        NaN      1.0
# GW151226-v2            0.04  1.000000e-07        NaN        NaN      1.0
#
#              p_astro_lower  p_astro_upper  final_mass_source  \
# id
# GW150914-v3            NaN            NaN               63.1
# GW151012-v3            NaN            NaN               35.6
# GW151226-v2            NaN            NaN               20.5
#
#              final_mass_source_lower  final_mass_source_upper
# id
# GW150914-v3                     -3.0                      3.4
# GW151012-v3                     -3.8                     10.8
# GW151226-v2                     -1.5                      6.4
#
# [3 rows x 42 columns]

# %%
gwtc_i.luminosity_distance
# Out:
# id
# GW150914-v3            440.0
# GW151012-v3           1080.0
# GW151226-v2            450.0
# GW170104-v2            990.0
# GW170608-v3            320.0
#                        ...
# GW200306_093714-v1    2100.0
# GW200308_173609-v1    5400.0
# GW200311_115853-v1    1170.0
# GW200316_215756-v1    1120.0
# GW200322_091133-v1    3600.0
# Name: luminosity_distance, Length: 93, dtype: float64

# %%
(gwtc_i.luminosity_distance.max() * astropy.units.Mpc).to('lightyear')
# Out:
# <Quantity 2.70057481e+10 lyr>

# %%
gwtc_i['total_mass_source']
# Out:
# id
# GW150914-v3            NaN
# GW151012-v3            NaN
# GW151226-v2            NaN
# GW170104-v2            NaN
# GW170608-v3            NaN
#                       ...
# GW200306_093714-v1    43.9
# GW200308_173609-v1    50.6
# GW200311_115853-v1    61.9
# GW200316_215756-v1    21.2
# GW200322_091133-v1    55.0
# Name: total_mass_source, Length: 93, dtype: float64

# %%
# gwtc_i['total_mass_source'] = gwtc_i['mass_1_source'] + gwtc_i['mass_2_source']

# %%
missing = np.isnan(gwtc_i.total_mass_source)

# %%
missing
# Out:
# id
# GW150914-v3            True
# GW151012-v3            True
# GW151226-v2            True
# GW170104-v2            True
# GW170608-v3            True
#                       ...
# GW200306_093714-v1    False
# GW200308_173609-v1    False
# GW200311_115853-v1    False
# GW200316_215756-v1    False
# GW200322_091133-v1    False
# Name: total_mass_source, Length: 93, dtype: bool

# %%
gwtc_i.loc[missing, 'total_mass_source'] = (gwtc_i.loc[missing, 'mass_1_source'] +
                                            gwtc_i.loc[missing, 'mass_2_source'])

# %%
gwtc_i['total_mass_source']
# Out:
# id
# GW150914-v3           66.2
# GW151012-v3           36.8
# GW151226-v2           21.4
# GW170104-v2           50.8
# GW170608-v3           18.6
#                       ...
# GW200306_093714-v1    43.9
# GW200308_173609-v1    50.6
# GW200311_115853-v1    61.9
# GW200316_215756-v1    21.2
# GW200322_091133-v1    55.0
# Name: total_mass_source, Length: 93, dtype: float64

# %%
pp.plot(gwtc_i.total_mass_source, gwtc_i.luminosity_distance, '.')
pp.xlabel('total mass (Msun)')
pp.ylabel('luminosity distance (Mpc)')
# Out:
# Text(0, 0.5, 'luminosity distance (Mpc)')

# %%
gwtc_i.plot.scatter('total_mass_source', 'luminosity_distance', s=50,
                    figsize=(9,6))
# Out:
# <Axes: xlabel='total_mass_source', ylabel='luminosity_distance'>

# %%
gwtc_i.plot.scatter('total_mass_source', 'luminosity_distance',
                    s=gwtc['network_matched_filter_snr'] * 15,  # some trial-and-error to set sizes just right
                    linewidth=1, edgecolors='w',                # a white contour helps tell spots apart
                    c=gwtc['redshift'], colormap='plasma',     # set colors using colormap 
                    sharex=False,    # make sure x label does not disappear (thanks, stackoverflow.com)
                    figsize=(10,6))
# Out:
# <Axes: xlabel='total_mass_source', ylabel='luminosity_distance'>

# %%
gwtc_i.plot.scatter('mass_1_source', 'mass_2_source',
                    s=gwtc['total_mass_source']*3,
                    linewidth=1, edgecolors='w',
                    c=gwtc['redshift'], colormap='plasma',
                    sharex=False, figsize=(10,6))

pp.plot([0,100],[0,100],'k:')
pp.plot([0,100],[0,50],'k:')
pp.plot([0,100],[0,20],'k:')

pp.axis([0,100,0,100]);
