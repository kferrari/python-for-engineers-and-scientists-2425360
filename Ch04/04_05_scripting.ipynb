# %% [markdown]
# # 04_05_scripting.ipynb - Automation with Python scripts

# %%
import os
import subprocess
import glob

import matplotlib.pyplot as pp

# %%
events = ['GW170817-v3', 'GW190521_074359-v1', 'GW190814-v2']

# %%
for event in events:
    p1 = subprocess.run(['python', 'hdfdownload.py', event], capture_output=True)
    p2 = subprocess.run(['python', 'plotsignal.py', event], capture_output=True)

# %%
p2.returncode
# Out:
# 0

# %%
print(p1.stderr.decode('ascii'))

# %%
print(p1.stdout.decode('ascii'))
# Out:
# Downloading https://gwosc.org/eventapi/json/GWTC-2/GW190814/v2 to ./GW190814-v2.json.
# Downloading https://gwosc.org/eventapi/json/GWTC-2/GW190814/v2/H-H1_GWOSC_4KHZ_R1-1249852241-32.hdf5 to ./H1-GW190814-v2.hdf5.
# Downloading https://gwosc.org/eventapi/json/GWTC-2/GW190814/v2/L-L1_GWOSC_4KHZ_R1-1249852241-32.hdf5 to ./L1-GW190814-v2.hdf5.

# %%
pngs = glob.glob('*.png')

# %%
pngs
# Out:
# ['GW190521_074359-v1.png', 'GW170817-v3.png', 'GW190814-v2.png']

# %% [markdown]
# #### The grand finale!

# %%
for png in pngs:
    pp.figure(figsize=(9,6))
    pp.imshow(pp.imread(png))
    pp.show()
